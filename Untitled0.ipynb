# %% [markdown]
# **İlk Deneme**
#
# deneme

# %%
ad=input('Öğrencinin İsimini Giriniz:')
soyad=input('Öğrencinin Soy Adını Giriniz:')
print("--------------")
print("Kayıt Başarılı")
print("--------------")
sayi=float(input('İlk Not:'))
sayi2=float(input('İkinci Not:'))
toplam=(sayi+sayi2)/2
print(ad,soyad,("Ortalama Puanı:"),toplam)
if toplam>=50:
  print('Öğrenci Dersi Başarıyla Geçti')
else:
    print('Öğrenci Dersi Gçemedi')
print("--------------")
print("Güncelleme Tamamlanmıştır")
print("--------------")
secim=input("Başka Bir Öğrencinin Güncelleme İşlemi Yapmak İçin 'Evet' İstemiyorsanız  'Hayır' Yazınız ")

if secim=='Evet':
  ad=input('Öğrencinin İsimini Giriniz:')
soyad=input('Öğrencinin Soy Adını Giriniz:')
print("--------------")
print("Kayıt Başarılı")
print("--------------")
sayi=float(input('İlk Not:'))
sayi2=float(input('İkinci Not:'))
toplam=(sayi+sayi2)/2
print(ad,soyad,("Ortalama Puanı:"),toplam)
if toplam>=50:
  print('Öğrenci Dersi Başarıyla Geçti')
else:
    print('Öğrenci Dersi Gçemedi')
print("--------------")
print("Güncelleme Tamamlanmıştır")
print("--------------")
secim=input("Başka Bir Öğrencinin Güncelleme İşlemi Yapmak İçin 'Evet' İstemiyorsanız  'Hayır' Yazınız ")
if secim=='Evet':
  print("Yeter Bu Kadar")
else: 
  print('İyi Günlerrr')
# Out:
# Öğrencinin İsimini Giriniz:Ali
# Öğrencinin Soy Adını Giriniz:Birdal
# --------------
# Kayıt Başarılı
# --------------
# İlk Not:1.47
# İkinci Not:0.90454
# Ali Birdal Ortalama Puanı: 1.18727
# Öğrenci Dersi Gçemedi
# --------------
# Güncelleme Tamamlanmıştır
# --------------
# Başka Bir Öğrencinin Güncelleme İşlemi Yapmak İçin 'Evet' İstemiyorsanız  'Hayır' Yazınız Evet
# Öğrencinin İsimini Giriniz:Hüseyin
# Öğrencinin Soy Adını Giriniz:Yeldan
# --------------
# Kayıt Başarılı
# --------------
# İlk Not:100
# İkinci Not:100
# Hüseyin Yeldan Ortalama Puanı: 100.0
# Öğrenci Dersi Başarıyla Geçti
# --------------
# Güncelleme Tamamlanmıştır
# --------------
# Başka Bir Öğrencinin Güncelleme İşlemi Yapmak İçin 'Evet' İstemiyorsanız  'Hayır' Yazınız Evet
# Yeter Bu Kadar
